# %% [markdown]
# ## Visualize molecule

# %%
from rdkit import Chem
# Out:
# RDKit WARNING: [15:27:59] Enabling RDKit 2019.09.3 jupyter extensions

# %%
smiles = 'Cc1ccc2NC(=O)N(Cc3cc(C)cc(C)c3)c2c1'
mol = Chem.MolFromSmiles(smiles)
mol
